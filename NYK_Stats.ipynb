# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.basketball-reference.com/teams/NYK/2023.html"

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find('table', id = 'per_game')

# %%
per_game_titles = table.find_all('th', class_ = 'poptip')

# %%
table_titles = [title.text for title in per_game_titles]

print(table_titles)
# Out:
# ['Rk', 'Player', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = table_titles)

df = df.drop('Rk', axis=1)
df
# Out:
# Empty DataFrame
# Columns: [Player, Age, G, GS, MP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 27 columns]

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    table_data = [data.text for data in row_data]
    
    length = len(df)
    df.loc[length] = table_data

# %%
df
# Out:
#                 Player Age   G  GS    MP   FG   FGA   FG%   3P  3PA  ...  \
# 0        Julius Randle  28  77  77  35.5  8.5  18.6  .459  2.8  8.3  ...
# 1        Jalen Brunson  26  68  68  35.0  8.6  17.6  .491  2.0  4.7  ...
# 2           RJ Barrett  22  73  73  33.9  7.0  16.1  .434  1.7  5.3  ...
# 3            Josh Hart  27  25   1  30.0  3.7   6.3  .586  1.1  2.1  ...
# 4       Quentin Grimes  22  71  66  29.9  4.0   8.5  .468  2.2  5.7  ...
# 5    Immanuel Quickley  23  81  21  28.9  5.2  11.6  .448  2.1  5.6  ...
# 6    Mitchell Robinson  24  59  58  27.0  3.2   4.7  .671  0.0  0.0  ...
# 7          Cam Reddish  23  20   8  21.9  3.1   6.8  .449  0.9  2.8  ...
# 8   Isaiah Hartenstein  24  82   8  19.8  2.1   4.0  .535  0.1  0.5  ...
# 9        Evan Fournier  30  27   7  17.0  2.1   6.1  .337  1.3  4.2  ...
# 10          Obi Toppin  24  67   5  15.7  2.8   6.3  .446  1.3  3.7  ...
# 11        Jericho Sims  24  52  16  15.6  1.6   2.1  .776  0.0  0.0  ...
# ...

# %%
df.to_csv(r'/Users/stephennunez/Documents/Web_Scraping/NYK_Stats.csv')
