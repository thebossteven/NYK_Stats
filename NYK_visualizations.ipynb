# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"/Users/stephennunez/repos/NYK_Stats/NYK_Stats.csv")
plt.style.use('seaborn-v0_8-pastel')

# %%
#group by wether the player is a starter or not(games started greater than 50)

df['Is Starter'] = ['Starter' if x > 50 else 'Not Starter' for x in df['GS']]
df.set_index('Player')

df_starter = df.groupby('Is Starter')

# %%
df_starter.get_group('Starter')
# Out:
#    Unnamed: 0             Player  Age   G  GS    MP   FG   FGA    FG%   3P  \
# 0           0      Julius Randle   28  77  77  35.5  8.5  18.6  0.459  2.8
# 1           1      Jalen Brunson   26  68  68  35.0  8.6  17.6  0.491  2.0
# 2           2         RJ Barrett   22  73  73  33.9  7.0  16.1  0.434  1.7
# 4           4     Quentin Grimes   22  71  66  29.9  4.0   8.5  0.468  2.2
# 6           6  Mitchell Robinson   24  59  58  27.0  3.2   4.7  0.671  0.0
#
#    ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Is Starter
# 0  ...  1.8  8.1  10.0  4.1  0.6  0.3  2.8  3.0  25.1     Starter
# 1  ...  0.6  3.0   3.5  6.2  0.9  0.2  2.1  2.2  24.0     Starter
# 2  ...  0.8  4.2   5.0  2.8  0.4  0.2  2.2  2.5  19.6     Starter
# 4  ...  0.7  2.5   3.2  2.1  0.7  0.4  1.0  2.5  11.3     Starter
# 6  ...  4.5  4.9   9.4  0.9  0.9  1.8  0.7  2.7   7.4     Starter
#
# [5 rows x 29 columns]

# %%
df_starter.plot(kind = 'bar', y = 'PTS', x = 'Player')
plt.tight_layout()
plt.savefig("Player_points.png")

# %%
df_starter.plot(kind = 'barh', y = 'FG%', x = 'Player')
plt.tight_layout()
plt.savefig("Player_FieldGoal.png")

# %%
knicks_ppg = df['PTS'].sum()
df_starter.sum().plot(kind = 'pie', y = 'PTS', autopct = '%1.0f%%')
plt.tight_layout()
plt.savefig("Points.png")
